# %% [markdown]
# Comparativa entre la variación del PIB ajustado por PPA, con el Índice de Libertad Económica en los años 2017, 2018 y 2019.
#
#
# Alan J. Orce Hernández
# Enero 2021

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (9,6)


# Se cargan los datos del fichero en un dataframe.
#Loading data file in a DataFrame
data = pd.read_csv("data/GDP_var.csv", skiprows=4)

a = data.shape

print("Total de entradas: ", a[0])
print("Total de variables: ", a[1])

data
# Out:
# Total de entradas:  266
# Total de variables:  66
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name     Indicator Code  1960      1961  \
# 0    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 1    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 2    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -0.211799
# 4    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# ..                                ...                ...   ...       ...
# 261  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 262  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN       NaN
# 263  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN  1.328134
# 264  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN -1.635258
# 265  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG   NaN  2.821534
#
#          1962      1963      1964       1965  ...       2012      2013  \
# 0         NaN       NaN       NaN        NaN  ...  -1.865105  3.592223
# 1         NaN       NaN       NaN        NaN  ...   0.353702  2.028548
# 2         NaN       NaN       NaN        NaN  ...   8.974865  1.974166
# 3    1.595322  5.029957  3.177737   1.770562  ...   2.454677  3.178794
# 4         NaN       NaN       NaN        NaN  ...   4.706519  1.291994
# ..        ...       ...       ...        ...  ...        ...       ...
# 261       NaN       NaN       NaN        NaN  ...   0.805676  4.702936
# 262       NaN       NaN       NaN        NaN  ...  -0.391864  2.014175
# 263  3.570381  4.707660  5.237069   3.448264  ...   0.789722  0.854344
# 264 -5.371127  0.215682  8.873040  13.143425  ...   4.310199  1.809749
# 265 -1.934893  2.697117 -4.403385   1.430334  ...  14.701077  0.192474
#
#          2014       2015       2016      2017      2018      2019      2020  \
# 0   -0.290534   5.129657   1.587869  1.519821       NaN       NaN       NaN
# 1    1.655829   0.285573  -0.406483  0.409547  0.002633 -0.570661 -5.394391
# 2   -0.665291  -1.622857  -0.541416  0.064764 -1.194900  1.535637 -4.575032
# 3    3.078499   0.091846  -2.543516 -0.429169  0.217701  0.501092 -3.502433
# 4    1.219881  -2.468737  -5.816188 -3.409983 -5.162112 -3.795608 -8.396241
# ..        ...        ...        ...       ...       ...       ...       ...
# 261  3.653588   7.371867   6.203623  4.038709  3.056665  5.237433 -4.620481
# 262 -2.802862 -29.827145 -11.611137 -7.345180 -1.594564       NaN       NaN
# 263 -0.179701  -0.218801  -0.806311 -0.265301  0.113021 -1.196091 -7.615876
# 264  1.480580  -0.187950   0.706659  0.494086  1.048034 -1.451364 -5.550283
# 265  0.596149   0.100575  -0.793105  3.192453  3.356166 -7.468627 -7.620388
#
#      Unnamed: 65
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 261          NaN
# 262          NaN
# 263          NaN
# 264          NaN
# 265          NaN
#
# [266 rows x 66 columns]

# %%
#Quitamos ultima columna.
#Drop last column.

data = data.drop(['Unnamed: 65'], axis=1)


#Como nos interesa solo los ultimos años, vamos a quitar desde 1960 hasta 2016.
#Dropping columns from 1960 to 2016

i = 1960
while i < 2017:
    data = data.drop([str(i)], axis=1)
    i = i +1
    
#Tambien 2020 por ser un año atipico, y habría que revisar la metodologia empleada.
#Being 2020 an anormal year, we drop it too.

data = data.drop(['2020'], axis=1)

#Se quitan filas donde no haya informacion.
#Dropping also rows with missing data

data = data.dropna(subset = ["2017","2018","2019"])

# %%
#Se comprueba que no falten datos en el dataframe
#Checking if there are missing values.


for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# Country Name - 0%
# Country Code - 0%
# Indicator Name - 0%
# Indicator Code - 0%
# 2017 - 0%
# 2018 - 0%
# 2019 - 0%

# %%
#Tipos de datos
#Variables types

print(data.dtypes)
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 2017              float64
# 2018              float64
# 2019              float64
# dtype: object

# %%
#Se muestran los valores atipicos
#Showing outliers

data.boxplot(column=['2017','2018','2019'])
# Out:
# <AxesSubplot:>

# %%
#Si hubiera algun error y alguna fila estuviera duplicada, la quitamos
#Dropping duplicate rows

data.drop_duplicates()
# Out:
#                     Country Name Country Code  \
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# 5                        Albania          ALB
# ..                           ...          ...
# 260                        Samoa          WSM
# 261                       Kosovo          XKX
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                        Indicator Name     Indicator Code      2017      2018  \
# 1    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.409547  0.002633
# 2    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.064764 -1.194900
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -0.429169  0.217701
# 4    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -3.409983 -5.162112
# 5    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.897741  4.276326
# ..                                ...                ...       ...       ...
# 260  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.619350 -1.620922
# 261  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  4.038709  3.056665
# 263  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG -0.265301  0.113021
# 264  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  0.494086  1.048034
# 265  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG  3.192453  3.356166
#
#          2019
# 1   -0.570661
# 2    1.535637
# 3    0.501092
# 4   -3.795608
# 5    2.549359
# ..        ...
# 260  3.868765
# 261  5.237433
# 263 -1.196091
# 264 -1.451364
# 265 -7.468627
#
# [251 rows x 7 columns]

# %%
# Se cargan los datos del Indice de Libertad Economica en otro dataframe.
#Loading Freedom Index file on another dataframe.

free_inx_2017 = pd.read_csv("data/freedom_index_2017.csv")

free_inx_2017
# Out:
#             Name  Index Year  Overall Score  Property Rights  \
# 0    Afghanistan        2017           48.9             12.6
# 1        Albania        2017           64.4             54.0
# 2        Algeria        2017           46.5             38.2
# 3         Angola        2017           48.5             36.4
# 4      Argentina        2017           50.4             32.4
# ..           ...         ...            ...              ...
# 181    Venezuela        2017           27.0              6.8
# 182      Vietnam        2017           52.4             49.7
# 183        Yemen        2017            NaN             37.3
# 184       Zambia        2017           55.8             49.6
# 185     Zimbabwe        2017           44.0             27.3
#
#      Government Integrity  Judicial Effectiveness  Tax Burden  \
# 0                    27.5                    28.4        91.6
# 1                    39.7                    28.5        86.9
# 2                    31.7                    29.6        81.1
# 3                    12.8                    19.8        87.7
# 4                    38.2                    39.6        62.6
# ..                    ...                     ...         ...
# 181                  11.6                    10.3        72.5
# 182                  24.6                    32.0        79.6
# 183                  17.4                    22.6         NaN
# 184                  35.0                    39.8        73.1
# 185                  14.7                    26.1        61.1
#
#      Government Spending  Fiscal Health  Business Freedom  Labor Freedom  \
# 0                   79.9           97.3              54.2           59.9
# 1                   72.5           51.5              79.3           50.7
# 2                   51.0           19.8              62.1           49.5
# 3                   58.6           70.7              58.5           40.4
# 4                   54.6           56.4              57.3           46.1
# ..                   ...            ...               ...            ...
# 181                 51.5           15.2              39.7           28.5
# 182                 74.6           21.1              61.2           62.2
# 183                 77.2           10.6              51.4           54.2
# 184                 81.6           21.6              66.6           48.2
# 185                 75.2           90.6              36.2           33.1
#
#      Monetary Freedom  Trade Freedom  Investment Freedom  Financial Freedom
# 0                69.3           66.0                 0.0                0.0
# 1                81.4           87.7                70.0               70.0
# 2                67.0           63.3                35.0               30.0
# 3                70.6           56.7                30.0               40.0
# 4                50.9           66.7                50.0               50.0
# ..                ...            ...                 ...                ...
# 181              16.8           60.7                 0.0               10.0
# 182              76.0           83.1                25.0               40.0
# 183              59.7            NaN                 NaN                NaN
# 184              70.7           78.3                55.0               50.0
# 185              76.5           52.8                25.0               10.0
#
# [186 rows x 15 columns]

# %%
#Vemos que no coinciden la cantidad de países. Mostramos las diferencias.
#Countries list don't match. So, we show differences.

ls_data = list(data["Country Name"])
ls_freed = list(free_inx_2017["Name"])


for nombre_freed in ls_freed:
    i = False
    for nombre_data in ls_data:
        if nombre_freed == nombre_data:
            i = True
    if i == False:
        print(nombre_freed)
# Out:
# Bangladesh
# Burma
# Côte d'Ivoire
# Democratic Republic of Congo
# Egypt
# Eritrea
# Hong Kong
# Iran
# Laos
# Liechtenstein
# Macau
# Micronesia
# North Korea
# Republic of Congo
# Russia
# Saint Lucia
# Saint Vincent and the Grenadines
# São Tomé and Príncipe
# Serbia
# South Korea
# Syria
# Taiwan
# The Bahamas
# The Gambia
# Venezuela
# Yemen

# %%
# Se reemplazan las inconsistencias
#Replacing values.

free_inx_2017 = free_inx_2017.replace(['Bangladesh '],'Bangladesh')
data = data.replace(['Myanmar'],'Burma')
free_inx_2017 = free_inx_2017.replace(["Côte d'Ivoire"],"Cote d'Ivoire")
data = data.replace(['Congo, Dem. Rep.'],'Democratic Republic of Congo')
data = data.replace(['Egypt, Arab Rep.'],'Egypt')
data = data.replace(['old value'],'new value')
data = data.replace(['Hong Kong SAR, China'],'Hong Kong')
data = data.replace(['Iran, Islamic Rep.'],'Iran')
data = data.replace(['Lao PDR'],'Laos')
data = data.replace(['Macao SAR, China'],'Macau')
data = data.replace(['Micronesia, Fed. Sts.'],'Micronesia')
data = data.replace(['Congo, Rep.'],'Republic of Congo')
data = data.replace(['Russian Federation'],'Russia')
data = data.replace(['St. Lucia'],'Saint Lucia')
data = data.replace(['St. Vincent and the Grenadines'],'Saint Vincent and the Grenadines')
data = data.replace(['Sao Tome and Principe'],'São Tomé and Príncipe')
free_inx_2017 = free_inx_2017.replace(['Serbia '],'Serbia')
data = data.replace(['Korea, Rep.'],'South Korea')
data = data.replace(['Syrian Arab Republic'],'Syria')
data = data.replace(['Bahamas, The'],'The Bahamas')
data = data.replace(['Gambia, The'],'The Gambia')

# %%
# Se carga dataset del año 2018
# Loading dataset from 2018

free_inx_2018 = pd.read_csv("data/freedom_index_2018.csv")

# Mostramos las diferencias
# Showing differences

ls_data = list(data["Country Name"])
ls_freed = list(free_inx_2018["Name"])


for nombre_freed in ls_freed:
    i = False
    for nombre_data in ls_data:
        if nombre_freed == nombre_data:
            i = True
    if i == False:
        print(nombre_freed)
# Out:
# Bangladesh
# Côte d'Ivoire
# Eritrea
# Liechtenstein
# North Korea
# Serbia
# Taiwan
# Venezuela
# Yemen

# %%
# Se corrigen. Las demas son filas quitadas.
# Correcting them. Others are missing rows.

free_inx_2018 = free_inx_2018.replace(['Bangladesh '],'Bangladesh')
free_inx_2018 = free_inx_2018.replace(["Côte d'Ivoire"],"Cote d'Ivoire")
free_inx_2018 = free_inx_2018.replace(['Serbia '],'Serbia')


# Cargamos dataset del año 2019

free_inx_2019 = pd.read_csv("data/freedom_index_2019.csv")

# Mostramos las diferencias

ls_data = list(data["Country Name"])
ls_freed = list(free_inx_2019["Name"])


for nombre_freed in ls_freed:
    i = False
    for nombre_data in ls_data:
        if nombre_freed == nombre_data:
            i = True
    if i == False:
        print(nombre_freed)
# Out:
# Bangladesh
# Côte d'Ivoire
# Eritrea
# Liechtenstein
# North Korea
# Serbia
# Taiwan
# Venezuela
# Yemen

# %%
# Se corrigen. Las demas son filas quitadas.
# Correcting them. Others are missing rows.

free_inx_2019 = free_inx_2019.replace(['Bangladesh '],'Bangladesh')
free_inx_2019 = free_inx_2019.replace(["Côte d'Ivoire"],"Cote d'Ivoire")
free_inx_2019 = free_inx_2019.replace(['Serbia '],'Serbia')

# %%
# Se cambian titulos.
# Changing titles.


for col in free_inx_2017.columns:
    if col != 'Name':
        free_inx_2017 = free_inx_2017.rename({col: col + " 2017", }, axis=1)

for col in free_inx_2018.columns:
    if col != "Name":
        free_inx_2018 = free_inx_2018.rename({col: col + " 2018", }, axis=1)

for col in free_inx_2019.columns:
    if col != "Name":
        free_inx_2019 = free_inx_2019.rename({col: col + " 2019", }, axis=1)
    
free_inx_2017
# Out:
#             Name  Index Year 2017  Overall Score 2017  Property Rights 2017  \
# 0    Afghanistan             2017                48.9                  12.6
# 1        Albania             2017                64.4                  54.0
# 2        Algeria             2017                46.5                  38.2
# 3         Angola             2017                48.5                  36.4
# 4      Argentina             2017                50.4                  32.4
# ..           ...              ...                 ...                   ...
# 181    Venezuela             2017                27.0                   6.8
# 182      Vietnam             2017                52.4                  49.7
# 183        Yemen             2017                 NaN                  37.3
# 184       Zambia             2017                55.8                  49.6
# 185     Zimbabwe             2017                44.0                  27.3
#
#      Government Integrity 2017  Judicial Effectiveness 2017  Tax Burden 2017  \
# 0                         27.5                         28.4             91.6
# 1                         39.7                         28.5             86.9
# 2                         31.7                         29.6             81.1
# 3                         12.8                         19.8             87.7
# 4                         38.2                         39.6             62.6
# ..                         ...                          ...              ...
# 181                       11.6                         10.3             72.5
# 182                       24.6                         32.0             79.6
# 183                       17.4                         22.6              NaN
# 184                       35.0                         39.8             73.1
# 185                       14.7                         26.1             61.1
#
#      Government Spending 2017  Fiscal Health 2017  Business Freedom 2017  \
# 0                        79.9                97.3                   54.2
# 1                        72.5                51.5                   79.3
# 2                        51.0                19.8                   62.1
# 3                        58.6                70.7                   58.5
# 4                        54.6                56.4                   57.3
# ..                        ...                 ...                    ...
# 181                      51.5                15.2                   39.7
# 182                      74.6                21.1                   61.2
# 183                      77.2                10.6                   51.4
# 184                      81.6                21.6                   66.6
# 185                      75.2                90.6                   36.2
#
#      Labor Freedom 2017  Monetary Freedom 2017  Trade Freedom 2017  \
# 0                  59.9                   69.3                66.0
# 1                  50.7                   81.4                87.7
# 2                  49.5                   67.0                63.3
# 3                  40.4                   70.6                56.7
# 4                  46.1                   50.9                66.7
# ..                  ...                    ...                 ...
# 181                28.5                   16.8                60.7
# 182                62.2                   76.0                83.1
# 183                54.2                   59.7                 NaN
# 184                48.2                   70.7                78.3
# 185                33.1                   76.5                52.8
#
#      Investment Freedom 2017  Financial Freedom 2017
# 0                        0.0                     0.0
# 1                       70.0                    70.0
# 2                       35.0                    30.0
# 3                       30.0                    40.0
# 4                       50.0                    50.0
# ..                       ...                     ...
# 181                      0.0                    10.0
# 182                     25.0                    40.0
# 183                      NaN                     NaN
# 184                     55.0                    50.0
# 185                     25.0                    10.0
#
# [186 rows x 15 columns]

# %%
# Se hace una union entre los dataframes del tipo inner join
# Making an inner join between dataframes

data_amp = pd.merge(left=free_inx_2017,right=free_inx_2018, left_on='Name', right_on='Name')

data_amp = pd.merge(left=data_amp,right=free_inx_2019, left_on='Name', right_on='Name')

data_amp
# Out:
#             Name  Index Year 2017  Overall Score 2017  Property Rights 2017  \
# 0    Afghanistan             2017                48.9                  12.6
# 1        Albania             2017                64.4                  54.0
# 2        Algeria             2017                46.5                  38.2
# 3         Angola             2017                48.5                  36.4
# 4      Argentina             2017                50.4                  32.4
# ..           ...              ...                 ...                   ...
# 181    Venezuela             2017                27.0                   6.8
# 182      Vietnam             2017                52.4                  49.7
# 183        Yemen             2017                 NaN                  37.3
# 184       Zambia             2017                55.8                  49.6
# 185     Zimbabwe             2017                44.0                  27.3
#
#      Government Integrity 2017  Judicial Effectiveness 2017  Tax Burden 2017  \
# 0                         27.5                         28.4             91.6
# 1                         39.7                         28.5             86.9
# 2                         31.7                         29.6             81.1
# 3                         12.8                         19.8             87.7
# 4                         38.2                         39.6             62.6
# ..                         ...                          ...              ...
# 181                       11.6                         10.3             72.5
# 182                       24.6                         32.0             79.6
# 183                       17.4                         22.6              NaN
# 184                       35.0                         39.8             73.1
# 185                       14.7                         26.1             61.1
#
#      Government Spending 2017  Fiscal Health 2017  Business Freedom 2017  ...  \
# 0                        79.9                97.3                   54.2  ...
# 1                        72.5                51.5                   79.3  ...
# 2                        51.0                19.8                   62.1  ...
# 3                        58.6                70.7                   58.5  ...
# 4                        54.6                56.4                   57.3  ...
# ..                        ...                 ...                    ...  ...
# 181                      51.5                15.2                   39.7  ...
# 182                      74.6                21.1                   61.2  ...
# 183                      77.2                10.6                   51.4  ...
# 184                      81.6                21.6                   66.6  ...
# 185                      75.2                90.6                   36.2  ...
#
#      Judicial Effectiveness 2019  Tax Burden 2019  Government Spending 2019  \
# 0                           29.6             91.7                      80.3
# 1                           30.6             86.3                      73.9
# 2                           36.2             76.4                      48.7
# 3                           26.6             83.9                      80.7
# 4                           44.5             69.3                      49.5
# ..                           ...              ...                       ...
# 181                         13.1             74.7                      58.1
# 182                         40.3             79.7                      74.1
# 183                         22.2              NaN                      83.7
# 184                         35.6             72.3                      80.1
# 185                         24.8             62.3                      74.5
#
#      Fiscal Health 2019  Business Freedom 2019  Labor Freedom 2019  \
# 0                  99.3                   49.2                60.4
# 1                  80.6                   69.3                52.7
# 2                  18.7                   61.6                49.9
# 3                  58.2                   55.7                58.8
# 4                  33.0                   56.4                46.9
# ..                  ...                    ...                 ...
# 181                17.6                   33.9                28.0
# 182                40.7                   63.5                62.8
# 183                 0.0                   45.1                49.8
# 184                12.3                   71.1                46.0
# 185                23.7                   33.4                43.3
#
#      Monetary Freedom 2019  Trade Freedom 2019  Investment Freedom 2019  \
# 0                     76.7                66.0                     10.0
# 1                     81.5                87.8                     70.0
# 2                     74.9                67.4                     30.0
# 3                     55.4                61.2                     30.0
# 4                     60.2                70.0                     55.0
# ..                     ...                 ...                      ...
# 181                    0.0                60.0                      0.0
# 182                   68.9                79.2                     30.0
# 183                   61.5                71.4                     50.0
# 184                   70.3                72.6                     55.0
# 185                   72.4                70.0                     25.0
#
#      Financial Freedom 2019
# 0                      10.0
# 1                      70.0
# 2                      30.0
# 3                      40.0
# 4                      60.0
# ..                      ...
# 181                    10.0
# 182                    40.0
# 183                     NaN
# 184                    50.0
# 185                    10.0
#
# [186 rows x 43 columns]

# %%
# Ahora entre el dataframe inicial y el de los indices de libertad economica.
# Now, between GDP variation dataframe and freedom dataframe.

data_amp = pd.merge(left=data,right=data_amp, left_on='Country Name', right_on='Name')

data_amp
# Out:
#              Country Name Country Code                    Indicator Name  \
# 0             Afghanistan          AFG  GDP per capita growth (annual %)
# 1                  Angola          AGO  GDP per capita growth (annual %)
# 2                 Albania          ALB  GDP per capita growth (annual %)
# 3    United Arab Emirates          ARE  GDP per capita growth (annual %)
# 4               Argentina          ARG  GDP per capita growth (annual %)
# ..                    ...          ...                               ...
# 175                 Samoa          WSM  GDP per capita growth (annual %)
# 176                Kosovo          XKX  GDP per capita growth (annual %)
# 177          South Africa          ZAF  GDP per capita growth (annual %)
# 178                Zambia          ZMB  GDP per capita growth (annual %)
# 179              Zimbabwe          ZWE  GDP per capita growth (annual %)
#
#         Indicator Code      2017      2018      2019                  Name  \
# 0    NY.GDP.PCAP.KD.ZG  0.064764 -1.194900  1.535637           Afghanistan
# 1    NY.GDP.PCAP.KD.ZG -3.409983 -5.162112 -3.795608                Angola
# 2    NY.GDP.PCAP.KD.ZG  3.897741  4.276326  2.549359               Albania
# 3    NY.GDP.PCAP.KD.ZG  1.011431 -0.320590  1.934431  United Arab Emirates
# 4    NY.GDP.PCAP.KD.ZG  1.757648 -3.601610 -2.994388             Argentina
# ..                 ...       ...       ...       ...                   ...
# 175  NY.GDP.PCAP.KD.ZG  0.619350 -1.620922  3.868765                 Samoa
# 176  NY.GDP.PCAP.KD.ZG  4.038709  3.056665  5.237433                Kosovo
# 177  NY.GDP.PCAP.KD.ZG -0.265301  0.113021 -1.196091          South Africa
# 178  NY.GDP.PCAP.KD.ZG  0.494086  1.048034 -1.451364                Zambia
# 179  NY.GDP.PCAP.KD.ZG  3.192453  3.356166 -7.468627              Zimbabwe
#
#      Index Year 2017  Overall Score 2017  ...  Judicial Effectiveness 2019  \
# 0               2017                48.9  ...                         29.6
# 1               2017                48.5  ...                         26.6
# 2               2017                64.4  ...                         30.6
# 3               2017                76.9  ...                         87.1
# 4               2017                50.4  ...                         44.5
# ..               ...                 ...  ...                          ...
# 175             2017                58.4  ...                         31.0
# 176             2017                67.9  ...                         53.5
# 177             2017                62.3  ...                         39.3
# 178             2017                55.8  ...                         35.6
# 179             2017                44.0  ...                         24.8
#
#      Tax Burden 2019  Government Spending 2019  Fiscal Health 2019  \
# 0               91.7                      80.3                99.3
# 1               83.9                      80.7                58.2
# 2               86.3                      73.9                80.6
# 3               99.2                      68.8                88.9
# 4               69.3                      49.5                33.0
# ..               ...                       ...                 ...
# 175             79.9                      62.3                93.6
# 176             92.5                      77.7                96.0
# 177             62.1                      67.6                62.6
# 178             72.3                      80.1                12.3
# 179             62.3                      74.5                23.7
#
#      Business Freedom 2019  Labor Freedom 2019  Monetary Freedom 2019  \
# 0                     49.2                60.4                   76.7
# 1                     55.7                58.8                   55.4
# 2                     69.3                52.7                   81.5
# 3                     79.9                81.1                   80.9
# 4                     56.4                46.9                   60.2
# ..                     ...                 ...                    ...
# 175                   77.0                78.2                   83.5
# 176                   73.8                64.9                   78.3
# 177                   64.3                59.1                   75.2
# 178                   71.1                46.0                   70.3
# 179                   33.4                43.3                   72.4
#
#      Trade Freedom 2019  Investment Freedom 2019  Financial Freedom 2019
# 0                  66.0                     10.0                    10.0
# 1                  61.2                     30.0                    40.0
# 2                  87.8                     70.0                    70.0
# 3                  84.4                     40.0                    60.0
# 4                  70.0                     55.0                    60.0
# ..                  ...                      ...                     ...
# 175                63.8                     55.0                    30.0
# 176                70.8                     65.0                    30.0
# 177                76.0                     45.0                    50.0
# 178                72.6                     55.0                    50.0
# 179                70.0                     25.0                    10.0
#
# [180 rows x 50 columns]

# %%
# Se quita la columna Name
# Dropping Name column

data_amp = data_amp.drop(['Name'], axis=1)


# Regresion lineal entre el indice de libertad economica y la varion del PIB en 2017.
# Linear regression between Freedom Index and GDP variation in 2017.

sns.regplot(x="Overall Score 2017", y="2017", data=data_amp)
# Out:
# <AxesSubplot:xlabel='Overall Score 2017', ylabel='2017'>

# %%
# Regresion lineal entre el indice de libertad economica y la varion del PIB en 2018.
# Linear regression between Freedom Index and GDP variation in 2018.

sns.regplot(x="Overall Score 2018", y="2018", data=data_amp)
# Out:
# <AxesSubplot:xlabel='Overall Score 2018', ylabel='2018'>

# %%
# Regresion lineal entre el indice de libertad economica y la varion del PIB en 2019.
# Linear regression between Freedom Index and GDP variation in 2019.

sns.regplot(x="Overall Score 2019", y="2019", data=data_amp)
# Out:
# <AxesSubplot:xlabel='Overall Score 2019', ylabel='2019'>

# %%
# Creamos un nuevo dataframe con solo los datos de la variacion del PIB y el puntaje del freedom index
# Creating a new dataframe with only GDP variation and Freedom index score values.

data_red = data_amp

list_names = ["Country Name", "2017", "2018", "2019", "Overall Score 2017", "Overall Score 2018", "Overall Score 2019"]


for col in data_red.columns:
    if not col in list_names:
        data_red = data_red.drop(col, axis=1)


data_red
# Out:
#              Country Name      2017      2018      2019  Overall Score 2017  \
# 0             Afghanistan  0.064764 -1.194900  1.535637                48.9
# 1                  Angola -3.409983 -5.162112 -3.795608                48.5
# 2                 Albania  3.897741  4.276326  2.549359                64.4
# 3    United Arab Emirates  1.011431 -0.320590  1.934431                76.9
# 4               Argentina  1.757648 -3.601610 -2.994388                50.4
# ..                    ...       ...       ...       ...                 ...
# 175                 Samoa  0.619350 -1.620922  3.868765                58.4
# 176                Kosovo  4.038709  3.056665  5.237433                67.9
# 177          South Africa -0.265301  0.113021 -1.196091                62.3
# 178                Zambia  0.494086  1.048034 -1.451364                55.8
# 179              Zimbabwe  3.192453  3.356166 -7.468627                44.0
#
#      Overall Score 2018  Overall Score 2019
# 0                  51.3                51.5
# 1                  48.6                50.6
# 2                  64.5                66.5
# 3                  77.6                77.6
# 4                  52.3                52.2
# ..                  ...                 ...
# 175                61.5                62.2
# 176                66.6                67.0
# 177                63.0                58.3
# 178                54.3                53.6
# 179                44.0                40.4
#
# [180 rows x 7 columns]

# %%
#Matriz de correlacion bajo el metodo Pearson
#Correlation matrix by Pearson method

data_red.corr(method ='pearson')
# Out:
#                         2017      2018      2019  Overall Score 2017  \
# 2017                1.000000  0.742970  0.305309            0.170968
# 2018                0.742970  1.000000  0.593432            0.173840
# 2019                0.305309  0.593432  1.000000            0.072043
# Overall Score 2017  0.170968  0.173840  0.072043            1.000000
# Overall Score 2018  0.212032  0.193495  0.097176            0.982392
# Overall Score 2019  0.225094  0.212598  0.113074            0.962735
#
#                     Overall Score 2018  Overall Score 2019
# 2017                          0.212032            0.225094
# 2018                          0.193495            0.212598
# 2019                          0.097176            0.113074
# Overall Score 2017            0.982392            0.962735
# Overall Score 2018            1.000000            0.981579
# Overall Score 2019            0.981579            1.000000

# %%
#Matriz de correlacion bajo el metodo Kendall
#Correlation matrix by Kendall method

data_red.corr(method ='kendall')
# Out:
#                         2017      2018      2019  Overall Score 2017  \
# 2017                1.000000  0.557169  0.374674            0.087624
# 2018                0.557169  1.000000  0.531471            0.055619
# 2019                0.374674  0.531471  1.000000            0.025045
# Overall Score 2017  0.087624  0.055619  0.025045            1.000000
# Overall Score 2018  0.112408  0.070669  0.040503            0.882441
# Overall Score 2019  0.127228  0.092624  0.065045            0.827550
#
#                     Overall Score 2018  Overall Score 2019
# 2017                          0.112408            0.127228
# 2018                          0.070669            0.092624
# 2019                          0.040503            0.065045
# Overall Score 2017            0.882441            0.827550
# Overall Score 2018            1.000000            0.890300
# Overall Score 2019            0.890300            1.000000

# %%
#Matriz de correlacion bajo el metodo Spearman
#Correlation matrix by Spearman method

data_red.corr(method ='spearman')
# Out:
#                         2017      2018      2019  Overall Score 2017  \
# 2017                1.000000  0.737323  0.503079            0.125112
# 2018                0.737323  1.000000  0.692032            0.082149
# 2019                0.503079  0.692032  1.000000            0.045552
# Overall Score 2017  0.125112  0.082149  0.045552            1.000000
# Overall Score 2018  0.165225  0.102923  0.070742            0.977678
# Overall Score 2019  0.184841  0.139811  0.105288            0.952092
#
#                     Overall Score 2018  Overall Score 2019
# 2017                          0.165225            0.184841
# 2018                          0.102923            0.139811
# 2019                          0.070742            0.105288
# Overall Score 2017            0.977678            0.952092
# Overall Score 2018            1.000000            0.975352
# Overall Score 2019            0.975352            1.000000

# %%
# Matriz de correlacion con grado de colores
# Correlation Matrix with colors

correlation_matrix = data_red.corr()

sns.heatmap(correlation_matrix, annot = True)

plt.title("Matriz de correlacion")

plt.show()

# %%
#Se generan los pares de correlacion
#Generation correlation pairs

correlation_matrix = data_amp.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs = corr_pairs.dropna()

print(corr_pairs)


#Se ordenan
#Sorting them

sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# Country Name            Country Name               1.000000
#                         Country Code               1.000000
#                         2017                       1.000000
#                         2018                       1.000000
#                         2019                       1.000000
#                                                      ...
# Financial Freedom 2019  Labor Freedom 2019         0.107205
#                         Monetary Freedom 2019      0.029406
#                         Trade Freedom 2019         0.132610
#                         Investment Freedom 2019    0.111259
#                         Financial Freedom 2019     1.000000
# Length: 1936, dtype: float64
# Government Integrity 2019  Financial Freedom 2017      -0.146925
# Financial Freedom 2017     Government Integrity 2019   -0.146925
# Investment Freedom 2019    Government Integrity 2019   -0.084231
# Government Integrity 2019  Investment Freedom 2019     -0.084231
# Fiscal Health 2018         Financial Freedom 2018      -0.079183
#                                                           ...
# Monetary Freedom 2017      Monetary Freedom 2017        1.000000
# Labor Freedom 2017         Labor Freedom 2017           1.000000
# Business Freedom 2017      Business Freedom 2017        1.000000
# Business Freedom 2018      Business Freedom 2018        1.000000
# Financial Freedom 2019     Financial Freedom 2019       1.000000
# Length: 1936, dtype: float64

# %%
# Se buscan las altas correlaciones (> 0.5)
#Searching high correlations (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]
strong_pairs = strong_pairs[abs(sorted_pairs) < 1]

print(strong_pairs)
# Out:
# Tax Burden 2019         Trade Freedom 2019        0.500294
# Trade Freedom 2019      Tax Burden 2019           0.500294
# Overall Score 2019      Trade Freedom 2018        0.500914
# Trade Freedom 2018      Overall Score 2019        0.500914
# Labor Freedom 2018      Property Rights 2019      0.501010
#                                                     ...
# 2017                    Business Freedom 2019     0.901324
# Country Name            Business Freedom 2019     0.901324
# Country Code            Business Freedom 2019     0.901324
# Financial Freedom 2019  Financial Freedom 2018    0.974524
# Financial Freedom 2018  Financial Freedom 2019    0.974524
# Length: 1158, dtype: float64

# %%
# se crean dos nuevas columnas con la media de cada indicador
# Creating two new columns with each indicator mean.

data_red_new = data_red

data_red_new["Average Freedom"] = (data_red_new["Overall Score 2017"] + data_red_new["Overall Score 2018"] + data_red_new["Overall Score 2019"]) / 3

data_red_new["Average GDP Variation"] = (data_red_new["2017"] + data_red_new["2018"] + data_red_new["2019"]) / 3

data_red_new
# Out:
#              Country Name      2017      2018      2019  Overall Score 2017  \
# 0             Afghanistan  0.064764 -1.194900  1.535637                48.9
# 1                  Angola -3.409983 -5.162112 -3.795608                48.5
# 2                 Albania  3.897741  4.276326  2.549359                64.4
# 3    United Arab Emirates  1.011431 -0.320590  1.934431                76.9
# 4               Argentina  1.757648 -3.601610 -2.994388                50.4
# ..                    ...       ...       ...       ...                 ...
# 175                 Samoa  0.619350 -1.620922  3.868765                58.4
# 176                Kosovo  4.038709  3.056665  5.237433                67.9
# 177          South Africa -0.265301  0.113021 -1.196091                62.3
# 178                Zambia  0.494086  1.048034 -1.451364                55.8
# 179              Zimbabwe  3.192453  3.356166 -7.468627                44.0
#
#      Overall Score 2018  Overall Score 2019  Average Freedom  \
# 0                  51.3                51.5        50.566667
# 1                  48.6                50.6        49.233333
# 2                  64.5                66.5        65.133333
# 3                  77.6                77.6        77.366667
# 4                  52.3                52.2        51.633333
# ..                  ...                 ...              ...
# 175                61.5                62.2        60.700000
# 176                66.6                67.0        67.166667
# 177                63.0                58.3        61.200000
# 178                54.3                53.6        54.566667
# 179                44.0                40.4        42.800000
#
#      Average GDP Variation
# 0                 0.135167
# 1                -4.122568
# 2                 3.574475
# 3                 0.875091
# 4                -1.612783
# ..                     ...
# 175               0.955731
# 176               4.110936
# 177              -0.449457
# 178               0.030252
# 179              -0.306669
#
# [180 rows x 9 columns]

# %%
# Los 10 paises con mayor crecimiento medio del PIB
# 10 first countries with higher GDP growth

CountryHigherPIB = data_red_new.groupby('Country Name')[["Average GDP Variation"]].sum()

CountryHigherPIB = CountryHigherPIB.sort_values('Average GDP Variation', ascending = False)[:10]

CountryHigherPIB = CountryHigherPIB['Average GDP Variation']

CountryHigherPIB
# Out:
# Country Name
# Libya         13.154001
# Bangladesh     6.638355
# Armenia        6.506317
# Ireland        6.313363
# China          6.042699
# Nepal          6.038084
# Moldova        5.984097
# Romania        5.923419
# Vietnam        5.915174
# Burma          5.641989
# Name: Average GDP Variation, dtype: float64

# %%
# Los 10 paises con mayor media de libertad economica
# 10 first countries with higher Freedom mean

CountryHigherFreedom = data_red_new.groupby('Country Name')[["Average Freedom"]].sum()

CountryHigherFreedom = CountryHigherFreedom.sort_values('Average Freedom', ascending = False)[:10]

CountryHigherFreedom = CountryHigherFreedom['Average Freedom']

CountryHigherFreedom
# Out:
# Country Name
# Hong Kong               90.066667
# Singapore               88.933333
# New Zealand             84.100000
# Switzerland             81.700000
# Australia               80.933333
# Ireland                 79.200000
# Estonia                 78.166667
# Canada                  77.966667
# United Kingdom          77.766667
# United Arab Emirates    77.366667
# Name: Average Freedom, dtype: float64

# %%
# Media de libertad economica vs media de la variacion el PIB
# Average Freedom vs Average GDP Variation

plt.scatter(x=data_red_new['Average Freedom'], y=data_red_new['Average GDP Variation'], alpha=0.5)
plt.title('Average Freedom vs Average GDP Variation')
plt.xlabel('Average Freedom')
plt.ylabel('Average GDP Variation')
plt.show()

# %%
# Variacion del PIB por año.
# GDP variation per year.

sns.swarmplot(data=data_red_new[["2017", "2018", "2019"]])
# Out:
# <AxesSubplot:>

# %%
# Indice de libertad economica
# Freedom Index

sns.stripplot(data=data_red_new[["Overall Score 2017", "Overall Score 2018", "Overall Score 2019"]])
# Out:
# <AxesSubplot:>
